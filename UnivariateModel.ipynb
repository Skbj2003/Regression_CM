# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("training_data.csv")
print(df.head())
# Out:
#    Gauging_station  Water_Level_Xt_1  24HrRF_Xt_1  Water_Level_Xt
# 0                1              2.90          NaN            1.50
# 1                2              5.00         23.2            3.71
# 2                3             12.68         44.3           11.05
# 3                4              1.60         51.7            1.81
# 4                5              1.28         81.2            0.87

# %%
print(df.shape)
print(df.isnull().sum())
# Out:
# (78, 4)
# Gauging_station     0
# Water_Level_Xt_1    0
# 24HrRF_Xt_1         2
# Water_Level_Xt      6
# dtype: int64

# %%
df_clean = df.drop(columns=["Gauging_station"]).reset_index(drop=True)

print(f"{df_clean}")
# Out:
#     Water_Level_Xt_1  24HrRF_Xt_1  Water_Level_Xt
# 0               2.90          NaN            1.50
# 1               5.00         23.2            3.71
# 2              12.68         44.3           11.05
# 3               1.60         51.7            1.81
# 4               1.28         81.2            0.87
# ..               ...          ...             ...
# 73              1.62         73.5             NaN
# 74              0.90         38.5            0.98
# 75              3.48         16.1            3.42
# 76              2.49         18.8            2.28
# 77              3.30         24.9            3.20
#
# [78 rows x 3 columns]

# %%
x=df_clean[['Water_Level_Xt_1']]
y=df_clean['Water_Level_Xt']

print(x.shape)
print(y.shape)
# Out:
# (78, 1)
# (78,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)


print(x_train.shape)
print(x_test.shape)
# Out:
# (62, 1)
# (16, 1)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 model=LinearRegression()
# ----> 2 model.fit(x_train,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:601, in LinearRegression.fit(self, X, y, sample_weight)
#     597 n_jobs_ = self.n_jobs
#     599 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 601 X, y = validate_data(
#     602     self,
#     603     X,
#     604     y,
# ...

# %%
b0 = model.intercept_      
b1 = model.coef_[0]       

print(f'Intercept : {b0:.6f}')
print(f'Coef X1   : {b1:.6f}')

print(f'\nEquation: Water_Level_Xt = {b0:.4f} + {b1:.4f}*X1 ')

# %%
y_pred=model.predict(x_test)
y_actual=y_test

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

r2   = r2_score(y_actual, y_pred)
mae  = mean_absolute_error(y_actual, y_pred)
rmse = np.sqrt(mean_squared_error(y_actual, y_pred))

print("=" * 40)
print("  MODEL PERFORMANCE METRICS")
print("=" * 40)
print(f"  R2   : {r2:.4f}  ")
print(f"  MAE  : {mae:.4f}  <- avg error in metres")
print(f"  RMSE : {rmse:.4f}  <- penalises large errors more")
print("=" * 40)
# Out:
# ...
#   MODEL PERFORMANCE METRICS
# ...
#   R2   : 0.9573
#   MAE  : 0.2754  <- avg error in metres
#   RMSE : 0.4080  <- penalises large errors more
# ...

# %%
#b=-0.0467
#b1= 0.95
